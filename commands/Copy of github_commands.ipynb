# %% [markdown]
# Mount Google Drive, will ask for authentication

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Change present working directory<br>("Github" folder must already be created)

# %%
# %cd /content/drive/MyDrive/Github/mouse-behavior-analysis
# Out:
# /content/drive/.shortcut-targets-by-id/1Pbd6cqzCNG5prKEQ4WSLObUaH4E0pEMk/Github/mouse-behavior-analysis

# %% [markdown]
# * Go to Github.com account and go to Settings, navigate to Developer settings and then click on Personal access tokens.
# * Click on Generate new token button on top right corner of the page.
# * Click the repo checkbox under Select scopes section
# * Click on Generate token button at the bottom of the page

# %% [markdown]
# Setup github for the future:

# %%
# !git config --global user.email "paulazhu@college.harvard.edu"
# !git config --global user.name "paulazoo"

# %%
# !git remote -v
# Out:
# origin	https://github.com/paulazoo/mouse-behavior-analysis.git (fetch)
# origin	https://github.com/paulazoo/mouse-behavior-analysis.git (push)

# %%
# !git add .
# !git commit -m "neural_networks folder storage"
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git push https://SECRET@github.com/paulazoo/mouse-behavior-analysis.git
# Out:
# Everything up-to-date
