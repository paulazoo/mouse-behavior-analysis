# %%
# !pip install awscli

# %% [markdown]
# Mount Google Drive, will ask for authentication

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Change present working directory<br>("Github" folder must already be created)

# %%
text = '''
[default]
aws_access_key_id = ACCESS_KEY_ID
aws_secret_access_key = SECRET_ACCESS_KEY
region = us-east-2
'''
path = "/content/drive/My Drive/Github/config/awscli.ini"
with open(path, 'w') as f:
   f.write(text)
# !cat /content/drive/My\ Drive/Github/config/awscli.ini

# %%
import os
# !export AWS_SHARED_CREDENTIALS_FILE=/content/drive/My\ Drive/Github/config/awscli.ini
path = "/content/drive/My Drive/Github/config/awscli.ini"
os.environ['AWS_SHARED_CREDENTIALS_FILE'] = path
print(os.environ['AWS_SHARED_CREDENTIALS_FILE'])
# Out:
# /content/drive/My Drive/Github/config/awscli.ini

# %%
# !aws s3 ls s3://mouse-behavioral-analysis-models --recursive --human-readable --summarize
# Out:
# Total Objects: 0
#    Total Size: 0 Bytes

# %%
# %cd /content/drive/MyDrive/Github/mouse-behavioral-analysis-models
# !aws s3 cp s3://mouse-behavioral-analysis-models/test test --recursive
# Out:
# /content/drive/.shortcut-targets-by-id/1Pbd6cqzCNG5prKEQ4WSLObUaH4E0pEMk/Github/models

# %%
# %cd /content/drive/MyDrive/Github/mouse-behavioral-analysis-models
# must actually have an object in there in order to upload directories
# !aws s3 cp iteration_2_custom_trained s3://mouse-behavioral-analysis-models/iteration_2_custom_trained --recursive
# Out:
# /content/drive/.shortcut-targets-by-id/1Pbd6cqzCNG5prKEQ4WSLObUaH4E0pEMk/Github/models
# upload: iteration_2_custom_trained/demo-me-2021-07-14_no_videos/dlc-models/.DS_Store to s3://mouse-behavioral-analysis-models/iteration_2_custom_trained/demo-me-2021-07-14_no_videos/dlc-models/.DS_Store
# upload: iteration_2_custom_trained/demo-me-2021-07-14_no_videos/config.yaml to s3://mouse-behavioral-analysis-models/iteration_2_custom_trained/demo-me-2021-07-14_no_videos/config.yaml
# upload: iteration_2_custom_trained/demo-me-2021-07-14_no_videos/behaviors/221002_PZ71_1_male_side.mat to s3://mouse-behavioral-analysis-models/iteration_2_custom_trained/demo-me-2021-07-14_no_videos/behaviors/221002_PZ71_1_male_side.mat
# upload: iteration_2_custom_trained/demo-me-2021-07-14_no_videos/behaviors/221002_PZ71_1_female_side.mat to s3://mouse-behavioral-analysis-models/iteration_2_custom_trained/demo-me-2021-07-14_no_videos/behaviors/221002_PZ71_1_female_side.mat
# ...
